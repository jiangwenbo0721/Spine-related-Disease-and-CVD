# %%
import math
import matplotlib
import os
import scanpy as sc
import anndata as ad
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mcolors
from matplotlib import rcParams
from matplotlib.pyplot import rc_context
import matplotlib.pyplot as plt
import scanpy as sc
os.chdir('/data1/new_home/wang_jialing/gzuo/Spine')

# %%
sc.set_figure_params(dpi=300, color_map="magma",fontsize=10,dpi_save=300,format='png',vector_friendly=True)

# %%
from matplotlib.colors import LinearSegmentedColormap

# Define the colors
colors = [(0.83, 0.83, 0.83), (1, 0, 0)]  # LightGrey and Red in normalized RGB
colors = [(0.83, 0.83, 0.83), (229/255, 127/255, 123/255)] 
# Create the colormap
cmap_name = 'lightgrey_to_red'
custom_cmap = LinearSegmentedColormap.from_list(cmap_name, colors)

# %%
from matplotlib.colors import ListedColormap

# Get the colors from the tab10 and tab20 colormaps
tab20 = plt.get_cmap('tab20').colors
tab20c = plt.get_cmap('tab20c').colors

# Combine the two colormaps
combined_colors = tab20 + tab20c

# %%
file1="/data1/swp_dir/sc_dataset/data/bypy_upload/c2f66cd5-4ff4-4578-876c-55783a57cf8f.h5ad"
adata_neu=sc.read_h5ad(file1)
newpath = '/data1/new_home/wang_jialing/gzuo/Spine/brain1' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
adata_neu

# %%
adata_neu.obsm['umap']=adata_neu.obsm['X_UMAP']

# %%
print(adata_neu.var.head())

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
gene_symbol_col='feature_name'
cell_type_col='supercluster_term'
filename='dot_plot.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)
filename='dot_plot.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)

# %%
# Suppose your AnnData object is named adata_neu
genes_of_interest = ['KIAA0753', 'MAEA', 'FBXW7', 'ATF7IP2', 'MAP3K3', 'CEP164', 'RNF212']

# Cluster plot
plot_name = 'cluster_plot.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        legend_loc="on data",
        # palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

plot_name = 'cluster_plot2.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        # palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

# Violin plot
filename = 'violin_plot.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(
        adata_neu,
        gene_symbols=gene_symbol_col,
        var_names=genes_of_interest,
        groupby=cell_type_col,
        save=filename,
        show=False,
        swap_axes=True
    )

# %%
# Suppose your AnnData object is named adata_neu
genes_of_interest = ['KIAA0753', 'MAEA', 'FBXW7', 'ATF7IP2', 'MAP3K3', 'CEP164', 'RNF212']

# Cluster plot
plot_name = 'cluster_plot.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        legend_loc="on data",
        # palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

plot_name = 'cluster_plot2.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        # palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

# Violin plot
filename = 'violin_plot.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(
        adata_neu,
        gene_symbols=gene_symbol_col,
        var_names=genes_of_interest,
        groupby=cell_type_col,
        save=filename,
        show=False,
        swap_axes=True
    )

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753', 'MAEA', 'FBXW7', 'ATF7IP2', 'MAP3K3', 'CEP164', 'RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Corrected calculation of the number of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array for easier indexing
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(
            adata_neu,
            color=[gene],
            ax=axs[i],
            gene_symbols=gene_symbol_col,
            frameon=False,
            show=False,
            legend_fontweight='bold',
            s=10,
            color_map=custom_cmap,
            colorbar_loc=None
        )
        # Get the current axes object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.5, pad=.01)

# Delete unused subplots if the number of genes is not a multiple of ncol
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_all.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_all.png', dpi=300)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753', 'MAEA', 'FBXW7', 'ATF7IP2', 'MAP3K3', 'CEP164', 'RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Corrected calculation of the number of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array for easier access
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(
            adata_neu,
            color=[gene],
            ax=axs[i],
            gene_symbols=gene_symbol_col,
            frameon=False,
            show=False,
            legend_fontweight='bold',
            s=10,
            color_map=custom_cmap,
            vmax='p99',
            colorbar_loc=None
        )
        # Get the current axes object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.4, pad=.01)

# Delete unused subplots if the number of genes is not a multiple of ncol
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_allp99.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_allp99.png', dpi=300)

# %%
file1="/data1/swp_dir/sc_dataset/data/bypy_upload/heart1.h5ad"
adata_neu=sc.read_h5ad(file1)
newpath = '/data1/new_home/wang_jialing/gzuo/Spine/heart1' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
adata_neu

# %%
print(adata_neu.var.head())

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
gene_symbol_col='feature_name'
cell_type_col='cell_type'
filename='dot_plot.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)
filename='dot_plot.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
tissue_col='tissue'
filename='dot_plot_tissue.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=tissue_col,cmap='Blues',show=False,
             save=filename)
filename='dot_plot_tissue.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=tissue_col,cmap='Blues',show=False,
             save=filename)
filename='dot_plot2.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=[tissue_col,cell_type_col],cmap='Blues',show=False,
             save=filename)
filename='dot_plot2.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=[tissue_col,cell_type_col],cmap='Blues',show=False,
             save=filename)

# %%
# Assuming your AnnData object is named adata_neu
genes_of_interest = ['KIAA0753', 'MAEA', 'FBXW7', 'ATF7IP2', 'MAP3K3', 'CEP164', 'RNF212']

# Cluster plot
plot_name = 'cluster_plot_tissue.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=tissue_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        # legend_loc="on data",
        # palette="Set1",
        title=' ',
        palette='tab20b',
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

plot_name = 'cluster_plot_tissue.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=tissue_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        # legend_loc="on data",
        # palette="Set1",
        title=' ',
        palette='tab20b',
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

# %%
filename='violin_plot_tissue.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,show=False,
             save=filename,swap_axes=True)
filename='violin_plot_tissue_cell.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=[tissue_col,cell_type_col],show=False,
             save=filename,swap_axes=True)

filename='violin_plot_tissue.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,show=False,
             save=filename,swap_axes=True)
filename='violin_plot_tissue_cell.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=[tissue_col,cell_type_col],show=False,
             save=filename,swap_axes=True)

# %%
# Assuming your AnnData object is named adata_neu
genes_of_interest = ['KIAA0753', 'MAEA', 'FBXW7', 'ATF7IP2', 'MAP3K3', 'CEP164', 'RNF212']

# Cluster plot
plot_name = 'cluster_plot.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        legend_loc="on data",
        # palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

plot_name = 'cluster_plot2.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        # palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

# Violin plot
filename = 'violin_plot.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(
        adata_neu,
        gene_symbols=gene_symbol_col,
        var_names=genes_of_interest,
        groupby=cell_type_col,
        save=filename,
        show=False,
        swap_axes=True
    )

# %%
# Assuming your AnnData object is named adata_neu
genes_of_interest = ['KIAA0753', 'MAEA', 'FBXW7', 'ATF7IP2', 'MAP3K3', 'CEP164', 'RNF212']

# Cluster plot
plot_name = 'cluster_plot.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        legend_loc="on data",
        # palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

plot_name = 'cluster_plot2.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        # palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

# Violin plot
filename = 'violin_plot.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(
        adata_neu,
        gene_symbols=gene_symbol_col,
        var_names=genes_of_interest,
        groupby=cell_type_col,
        save=filename,
        show=False,
        swap_axes=True
    )

# %%
# Assuming your AnnData object is named adata_neu and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753', 'MAEA', 'FBXW7', 'ATF7IP2', 'MAP3K3', 'CEP164', 'RNF212']

# Calculate the number of rows based on the number of genes and columns
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Adjust the number of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array to easily access each axis
axs = axs.flatten()

# Loop through each gene and plot it on its respective subplot
for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(
            adata_neu,
            color=[gene],
            ax=axs[i],
            gene_symbols=gene_symbol_col,
            frameon=False,
            show=False,
            legend_fontweight='bold',
            s=10,
            color_map=custom_cmap,
            colorbar_loc=None
        )
        # Get the current axis object
        ax = axs[i]
        # Add a colorbar to the plot
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.5, pad=.01)

# Remove any extra axes if the number of genes is less than the number of subplots
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

# Disable interactive plotting and adjust layout
plt.ioff()
plt.tight_layout()

# Save the plot as PDF and PNG
plt.savefig('feature_plot_all.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_all.png', dpi=300)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753', 'MAEA', 'FBXW7', 'ATF7IP2', 'MAP3K3', 'CEP164', 'RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Adjust the number of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array to easily access each axis
axs = axs.flatten()

# Loop through each gene and plot it on its respective subplot
for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(
            adata_neu,
            color=[gene],
            ax=axs[i],
            gene_symbols=gene_symbol_col,
            frameon=False,
            show=False,
            legend_fontweight='bold',
            s=10,
            color_map=custom_cmap,
            vmax='p99',  # Scale the color to the 99th percentile
            colorbar_loc=None
        )
        # Get the current axis object
        ax = axs[i]
        # Add a colorbar to the plot
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.4, pad=.01)

# Remove any extra axes if the number of genes is less than the number of subplots
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

# Disable interactive plotting and adjust layout
plt.ioff()
plt.tight_layout()

# Save the plot as PDF and PNG
plt.savefig('feature_plot_allp99.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_allp99.png', dpi=300)

# %%
file1="/data1/swp_dir/sc_dataset/data/bypy_upload/artery2.h5ad"
adata_neu=sc.read_h5ad(file1)
newpath = '/data1/new_home/wang_jialing/gzuo/Spine/artery2' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
adata_neu

# %%
print(adata_neu.var.head())

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
gene_symbol_col='feature_name'
cell_type_col='cell_type'
filename='dot_plot.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)
filename='dot_plot.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)

# %%
# Assuming adata_neu is your AnnData object
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
# cluster plot
plot_name='cluster_plot.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False, legend_loc="on data",
#               palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)
plot_name='cluster_plot2.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False,
#               palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

# violin plot
filename='violin_plot.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
                         save=filename, show=False, swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
# cluster plot
plot_name='cluster_plot.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False, legend_loc="on data",
#               palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)
plot_name='cluster_plot2.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False,
#               palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

# violin plot
filename='violin_plot.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
                         save=filename, show=False, swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Fixing the row count calculation

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array to easily access each axis
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.5, pad=.01)

for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])
plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_all.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_all.png', dpi=300)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Correctly calculate the number of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the array of subplots so we can access them one by one
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, vmax='p99', colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical',shrink=.4,pad=.01)

for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])
    
# Turn off interactive mode, save, and output the figure
plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_allp99.pdf',dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_allp99.png',dpi=300)

# %%
file1="/data1/swp_dir/sc_dataset/data/bypy_upload/spinal1.h5ad"
adata_neu=sc.read_h5ad(file1)
newpath = '/data1/new_home/wang_jialing/gzuo/Spine/spinal1' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
adata_neu

# %%
adata_neu.obsm['umap']=adata_neu.obsm['X_UMAP']

# %%
print(adata_neu.var.head())

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
gene_symbol_col='feature_name'
cell_type_col='cell_type'
filename='dot_plot.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)
filename='dot_plot.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)

# %%
# Assuming adata_neu is your AnnData object
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
# cluster plot
plot_name='cluster_plot.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col,gene_symbols=gene_symbol_col,save=plot_name,show=False,
              frameon=False,legend_loc="on data",
#               palette="Set1",
               title=' ',
               palette=combined_colors,
              legend_fontweight='bold',legend_fontsize=8,s=10,
    legend_fontoutline=1)
plot_name='cluster_plot2.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col,gene_symbols=gene_symbol_col,save=plot_name,show=False,
              frameon=False,
#               palette="Set1",
               title=' ',
               palette=combined_colors,
              legend_fontweight='bold',legend_fontsize=8,s=10,
    legend_fontoutline=1)

# violin plot
filename='violin_plot.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,
             save=filename,show=False,swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
# cluster plot
plot_name='cluster_plot.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col,gene_symbols=gene_symbol_col,save=plot_name,show=False,
              frameon=False,legend_loc="on data",
#               palette="Set1",
               title=' ',
               palette=combined_colors,
              legend_fontweight='bold',legend_fontsize=8,s=10,
    legend_fontoutline=1)
plot_name='cluster_plot2.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col,gene_symbols=gene_symbol_col,save=plot_name,show=False,
              frameon=False,
#               palette="Set1",
               title=' ',
               palette=combined_colors,
              legend_fontweight='bold',legend_fontsize=8,s=10,
    legend_fontoutline=1)

# violin plot
filename='violin_plot.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,
             save=filename,show=False,swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Adjusting the number of rows calculation

# Creating subplots with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the array of subplots to make them easier to access one by one
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        # Plotting UMAP
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, colorbar_loc=None)
        # Getting the current axis object
        ax = axs[i]
        # Add colorbar
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.5, pad=.01)

# Removing extra subplot axes if there are more axes than genes
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

# Turn off interactive mode
plt.ioff()

# Adjust layout and save the image
plt.tight_layout()
plt.savefig('feature_plot_all.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_all.png', dpi=300)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Adjusting the number of rows calculation

# Creating subplots with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the array of subplots to make them easier to access one by one
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        # Plotting UMAP
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, vmax='p99', colorbar_loc=None)
        # Getting the current axis object
        ax = axs[i]
        # Add colorbar
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.4, pad=.01)

# Removing extra subplot axes if there are more axes than genes
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

# Turn off interactive mode
plt.ioff()

# Adjust layout and save the image
plt.tight_layout()
plt.savefig('feature_plot_allp99.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_allp99.png', dpi=300)

# %%
file1="/data1/swp_dir/sc_dataset/data/bypy_upload/lymph_node1.h5ad"
adata_neu=sc.read_h5ad(file1)
newpath = '/data1/new_home/wang_jialing/gzuo/Spine/lymph_node1' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
adata_neu

# %%
print(adata_neu.var.head())

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
gene_symbol_col='feature_name'
cell_type_col='cell_type'
filename='dot_plot.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)
filename='dot_plot.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)

# %%
# Assuming your AnnData object is named adata_neu
genes_of_interest = ['KIAA0753', 'MAEA', 'FBXW7', 'ATF7IP2', 'MAP3K3', 'CEP164', 'RNF212']

# Cluster plot
plot_name = 'cluster_plot.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False, legend_loc="on data",
               # palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

plot_name = 'cluster_plot2.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False,
               # palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

# Violin plot
filename = 'violin_plot.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
                         save=filename, show=False, swap_axes=True)

# %%
# Assuming your AnnData object is named adata_neu
genes_of_interest = ['KIAA0753', 'MAEA', 'FBXW7', 'ATF7IP2', 'MAP3K3', 'CEP164', 'RNF212']

# Cluster plot
plot_name = 'cluster_plot.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False, legend_loc="on data",
               # palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

plot_name = 'cluster_plot2.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False,
               # palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

# Violin plot
filename = 'violin_plot.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
                         save=filename, show=False, swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Correcting the number of rows

# Create subplots with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the array of subplots for easier access
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.5, pad=.01)

# Remove unused subplots
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_all.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_all.png', dpi=300)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Correcting the number of rows

# Create subplots with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the array of subplots for easier access
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, vmax='p99', colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.4, pad=.01)

# Remove unused subplots
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_allp99.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_allp99.png', dpi=300)

# %%
file1="/data1/swp_dir/sc_dataset/data/bypy_upload/spleen2.h5ad"
adata_neu=sc.read_h5ad(file1)
newpath = '/data1/new_home/wang_jialing/gzuo/Spine/spleen2' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
adata_neu

# %%
print(adata_neu.var.head())

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
gene_symbol_col='feature_name'
cell_type_col='cell_type'
filename='dot_plot.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)
filename='dot_plot.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)

# %%
# Assuming adata_neu is your AnnData object
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']

# Cluster plot
plot_name='cluster_plot.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False, legend_loc="on data",
               # palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

plot_name='cluster_plot2.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False,
               # palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

# Violin plot
filename='violin_plot.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
                         save=filename, show=False, swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']

# Cluster plot
plot_name='cluster_plot.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False, legend_loc="on data",
               # palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

plot_name='cluster_plot2.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False,
               # palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

# Violin plot
filename='violin_plot.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
                         save=filename, show=False, swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Fix the calculation of rows

# Create a subplot grid with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the axis array for easy access
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.5, pad=.01)

# Remove extra axes if the number of genes is less than the number of subplots
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_all.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_all.png', dpi=300)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Fix the calculation of rows

# Create a subplot grid with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the axis array for easy access
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, vmax='p99', colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.4, pad=.01)

# Remove extra axes if the number of genes is less than the number of subplots
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_allp99.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_allp99.png', dpi=300)
