# %%
import math
import matplotlib
import os
import scanpy as sc
import anndata as ad
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mcolors
from matplotlib import rcParams
from matplotlib.pyplot import rc_context
import matplotlib.pyplot as plt
import scanpy as sc
os.chdir('/data1/new_home/wang_jialing/gzuo/Spine')

# %%
sc.set_figure_params(dpi=300, color_map="magma",fontsize=10,dpi_save=300,format='png',vector_friendly=True)

# %%
from matplotlib.colors import LinearSegmentedColormap

# Define the colors
colors = [(0.83, 0.83, 0.83), (1, 0, 0)]  # LightGrey and Red in normalized RGB
colors = [(0.83, 0.83, 0.83), (229/255, 127/255, 123/255)] 
# Create the colormap
cmap_name = 'lightgrey_to_red'
custom_cmap = LinearSegmentedColormap.from_list(cmap_name, colors)

# %%
from matplotlib.colors import ListedColormap

# Get the colors from the tab10 and tab20 colormaps
tab20 = plt.get_cmap('tab20').colors
tab20c = plt.get_cmap('tab20c').colors

# Combine the two colormaps
combined_colors = tab20 + tab20c

# %%
file1="/data1/swp_dir/sc_dataset/data/bypy_upload/liver1.h5ad"
adata_neu=sc.read_h5ad(file1)
newpath = '/data1/new_home/wang_jialing/gzuo/Spine/liver1' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
adata_neu

# %%
print(adata_neu.var.head())

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
gene_symbol_col='feature_name'
cell_type_col='cell_type'
filename='dot_plot.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)
filename='dot_plot.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']

# Cluster plot
plot_name='cluster_plot.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False, legend_loc="on data",
               # palette="Set1",  # Uncomment if you want to use a different palette
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

plot_name='cluster_plot2.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False,
               # palette="Set1",  # Uncomment if you want to use a different palette
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

# Violin plot
filename='violin_plot.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
                         save=filename, show=False, swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']

# Cluster plot
plot_name='cluster_plot.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False, legend_loc="on data",
               # palette="Set1",  # Uncomment if you want to use a different palette
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

plot_name='cluster_plot2.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False,
               # palette="Set1",  # Uncomment if you want to use a different palette
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

# Violin plot
filename='violin_plot.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
                         save=filename, show=False, swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Adjust the calculation of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the array of subplots for easier access
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.5, pad=.01)

# Remove extra subplots if there are more axes than genes
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

plt.ioff()  # Turn off interactive plotting
plt.tight_layout()  # Adjust layout to make it compact

# Save the final plot as a PDF and PNG file
plt.savefig('feature_plot_all.pdf', dpi=300)
plt.tight_layout()  # Ensure everything fits properly
plt.savefig('feature_plot_all.png', dpi=300)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Adjust the calculation of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the array of subplots for easier access
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, vmax='p99', colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.4, pad=.01)

# Remove extra subplots if there are more axes than genes
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

plt.ioff()  # Turn off interactive plotting
plt.tight_layout()  # Adjust layout to make it compact

# Save the final plot as a PDF and PNG file
plt.savefig('feature_plot_allp99.pdf', dpi=300)
plt.tight_layout()  # Ensure everything fits properly
plt.savefig('feature_plot_allp99.png', dpi=300)

# %%
file1="/data1/swp_dir/sc_dataset/data/bypy_upload/pancreas_up/pancreas1.h5ad"
adata_neu=sc.read_h5ad(file1)
newpath = '/data1/new_home/wang_jialing/gzuo/Spine/pancreas1' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
adata_neu

# %%
print(adata_neu.var.head())

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
gene_symbol_col='feature_name'
cell_type_col='cell_type'
filename='dot_plot.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)
filename='dot_plot.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)

# %%
# Assuming adata_neu is your AnnData object
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
# Cluster plot
plot_name='cluster_plot.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
              frameon=False, legend_loc="on data",
#               palette="Set1",
               title=' ',
               palette=combined_colors,
              legend_fontweight='bold', legend_fontsize=8, s=10,
    legend_fontoutline=1)
plot_name='cluster_plot2.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
              frameon=False,
#               palette="Set1",
               title=' ',
               palette=combined_colors,
              legend_fontweight='bold', legend_fontsize=8, s=10,
    legend_fontoutline=1)

# Violin plot
filename='violin_plot.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
             save=filename, show=False, swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
# Cluster plot
plot_name='cluster_plot.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
              frameon=False, legend_loc="on data",
#               palette="Set1",
               title=' ',
               palette=combined_colors,
              legend_fontweight='bold', legend_fontsize=8, s=10,
    legend_fontoutline=1)
plot_name='cluster_plot2.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
              frameon=False,
#               palette="Set1",
               title=' ',
               palette=combined_colors,
              legend_fontweight='bold', legend_fontsize=8, s=10,
    legend_fontoutline=1)

# Violin plot
filename='violin_plot.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
             save=filename, show=False, swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Fix calculation of the number of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array to easily access each subplot
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.5, pad=.01)

for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])
plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_all.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_all.png', dpi=300)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Fix calculation of the number of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array to easily access each subplot
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, vmax='p99', colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.4, pad=.01)

for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])
plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_allp99.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_allp99.png', dpi=300)

# %%
file1="/data1/swp_dir/sc_dataset/data/bypy_upload/visceral_fat1.h5ad"
adata_neu=sc.read_h5ad(file1)
newpath = '/data1/new_home/wang_jialing/gzuo/Spine/visceral_fat1' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
adata_neu

# %%
print(adata_neu.var.head())

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
gene_symbol_col='feature_name'
cell_type_col='cell_type'
filename='dot_plot.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)
filename='dot_plot.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)

# %%
# Assuming adata_neu is your AnnData object
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
# cluster plot
plot_name='cluster_plot.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False, legend_loc="on data",
#               palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)
plot_name='cluster_plot2.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False,
#               palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

# violin plot
filename='violin_plot.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
                         save=filename, show=False, swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
# cluster plot
plot_name='cluster_plot.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False, legend_loc="on data",
#               palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)
plot_name='cluster_plot2.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False,
#               palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

# violin plot
filename='violin_plot.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
                         save=filename, show=False, swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Fix the calculation of the number of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array to access each subplot easily
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.5, pad=.01)

for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])
plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_all.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_all.png', dpi=300)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Fix the calculation of the number of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array to access each subplot easily
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, vmax='p99', colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=.4, pad=.01)

for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])
plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_allp99.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_allp99.png', dpi=300)

# %%
file1="/data1/swp_dir/sc_dataset/data/bypy_upload/omental_fat.h5ad"
adata_neu=sc.read_h5ad(file1)
newpath = '/data1/new_home/wang_jialing/gzuo/Spine/omental_fat' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
adata_neu

# %%
print(adata_neu.var.head())

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
gene_symbol_col='feature_name'
cell_type_col='cell_type'
filename='dot_plot.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)
filename='dot_plot.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)

# %%
# Assuming adata_neu is your AnnData object
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
# cluster plot
plot_name='cluster_plot.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
              frameon=False, legend_loc="on data",
#               palette="Set1",
               title=' ',
               palette=combined_colors,
              legend_fontweight='bold', legend_fontsize=8, s=10,
    legend_fontoutline=1)
plot_name='cluster_plot2.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
              frameon=False,
#               palette="Set1",
               title=' ',
               palette=combined_colors,
              legend_fontweight='bold', legend_fontsize=8, s=10,
    legend_fontoutline=1)

# violin plot
filename='violin_plot.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
             save=filename, show=False, swap_axes=True)

# %%
# Assuming your AnnData object is named adata_neu
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']

# Cluster plot
plot_name='cluster_plot.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False, legend_loc="on data",
#               palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

plot_name='cluster_plot2.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False,
#               palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

# Violin plot
filename='violin_plot.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
                          save=filename, show=False, swap_axes=True)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Correctly calculate number of rows

# Create a grid of subplots with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the axes array for easy access
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=0.5, pad=0.01)

# Delete any unused subplots
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_all.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_all.png', dpi=300)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Correctly calculate the number of rows

# Create a subplot layout with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot axes array for easier access
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, vmax='p99', colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=0.4, pad=0.01)

# Remove extra subplots if any
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_allp99.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_allp99.png', dpi=300)

# %%
file1="/data1/swp_dir/sc_dataset/data/bypy_upload/subcutaneous_adi1.h5ad"
adata_neu=sc.read_h5ad(file1)
newpath = '/data1/new_home/wang_jialing/gzuo/Spine/subcutaneous_adi1' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
adata_neu

# %%
print(adata_neu.var.head())

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
gene_symbol_col='feature_name'
cell_type_col='cell_type'
filename='dot_plot.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)
filename='dot_plot.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)

# %%
# Assuming your AnnData object is named adata_neu
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']

# Cluster plot
plot_name = 'cluster_plot.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False, legend_loc="on data",
#               palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

plot_name = 'cluster_plot2.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(adata_neu, color=cell_type_col, gene_symbols=gene_symbol_col, save=plot_name, show=False,
               frameon=False,
#               palette="Set1",
               title=' ',
               palette=combined_colors,
               legend_fontweight='bold', legend_fontsize=8, s=10,
               legend_fontoutline=1)

# Violin plot
filename = 'violin_plot.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(adata_neu, gene_symbols=gene_symbol_col, var_names=genes_of_interest, groupby=cell_type_col,
                         save=filename, show=False, swap_axes=True)

# %%
# Assuming your AnnData object is named adata_neu
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']

# Cluster plot
plot_name = 'cluster_plot.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        legend_loc="on data",
#       palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

plot_name = 'cluster_plot2.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
#       palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

# Violin plot
filename = 'violin_plot.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(
        adata_neu,
        gene_symbols=gene_symbol_col,
        var_names=genes_of_interest,
        groupby=cell_type_col,
        save=filename,
        show=False,
        swap_axes=True
    )

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Corrected calculation of number of rows

# Create a figure with nrow rows and ncol columns of subplots
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array for easier access
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(
            adata_neu,
            color=[gene],
            ax=axs[i],
            gene_symbols=gene_symbol_col,
            frameon=False,
            show=False,
            legend_fontweight='bold',
            s=10,
            color_map=custom_cmap,
            colorbar_loc=None
        )
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=0.5, pad=0.01)

# Delete unused subplots (if any)
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_all.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_all.png', dpi=300)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Correct the calculation of number of rows

# Create a subplot grid with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array for easier iteration
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(
            adata_neu,
            color=[gene],
            ax=axs[i],
            gene_symbols=gene_symbol_col,
            frameon=False,
            show=False,
            legend_fontweight='bold',
            s=10,
            color_map=custom_cmap,
            vmax='p99',               # Clip color scale at 99th percentile
            colorbar_loc=None
        )
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical', shrink=0.4, pad=0.01)

# Remove any unused subplots
for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])

plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_allp99.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_allp99.png', dpi=300)

# %%
file1="/data1/swp_dir/sc_dataset/data/bypy_upload/bone_marrow1.h5ad"
adata_neu=sc.read_h5ad(file1)
newpath = '/data1/new_home/wang_jialing/gzuo/Spine/bone_marrow1' 
if not os.path.exists(newpath):
    os.makedirs(newpath)
os.chdir(newpath)
adata_neu

# %%
print(adata_neu.var.head())

# %%
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
gene_symbol_col='feature_name'
cell_type_col='cell_type'
filename='dot_plot.pdf'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)
filename='dot_plot.png'
sc.pl.dotplot(adata_neu,gene_symbols=gene_symbol_col,var_names=genes_of_interest, groupby=cell_type_col,cmap='Blues',
             save=filename,show=False)

# %%
# Assuming your AnnData object is named adata_neu
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']

# Cluster plot
plot_name = 'cluster_plot.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        legend_loc="on data",
        # palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

plot_name = 'cluster_plot2.pdf'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        # palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

# Violin plot
filename = 'violin_plot.pdf'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(
        adata_neu,
        gene_symbols=gene_symbol_col,
        var_names=genes_of_interest,
        groupby=cell_type_col,
        save=filename,
        show=False,
        swap_axes=True
    )

# %%
# Assuming your AnnData object is named adata_neu
genes_of_interest = ['KIAA0753', 'MAEA', 'FBXW7', 'ATF7IP2', 'MAP3K3', 'CEP164', 'RNF212']

# Cluster plot
plot_name = 'cluster_plot.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        legend_loc="on data",
        # palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

plot_name = 'cluster_plot2.png'
with rc_context({"figure.figsize": (10, 10)}):
    sc.pl.umap(
        adata_neu,
        color=cell_type_col,
        gene_symbols=gene_symbol_col,
        save=plot_name,
        show=False,
        frameon=False,
        # palette="Set1",
        title=' ',
        palette=combined_colors,
        legend_fontweight='bold',
        legend_fontsize=8,
        s=10,
        legend_fontoutline=1
    )

# Violin plot
filename = 'violin_plot.png'
with rc_context({"figure.figsize": (20, 12)}):
    sc.pl.stacked_violin(
        adata_neu,
        gene_symbols=gene_symbol_col,
        var_names=genes_of_interest,
        groupby=cell_type_col,
        save=filename,
        show=False,
        swap_axes=True
    )

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Correct the calculation of the number of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array for easier access
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical',shrink=.5,pad=.01)

for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])
plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_all.pdf',dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_all.png',dpi=300)

# %%
# Assuming adata_neu is your AnnData object and genes_of_interest is your gene list
genes_of_interest = ['KIAA0753','MAEA','FBXW7','ATF7IP2','MAP3K3','CEP164','RNF212']
ncol = 2
nrow = math.ceil(len(genes_of_interest) / ncol)  # Correct the calculation of the number of rows

# Create a subplot with nrow rows and ncol columns
fig, axs = plt.subplots(nrow, ncol, figsize=(5 * ncol, 5 * nrow))

# Flatten the subplot array for easier access
axs = axs.flatten()

for i, gene in enumerate(genes_of_interest):
    with rc_context({"figure.figsize": (5, 5)}):
        sc.pl.umap(adata_neu, color=[gene], ax=axs[i], gene_symbols=gene_symbol_col, frameon=False, show=False,
                   legend_fontweight='bold', s=10, color_map=custom_cmap, vmax='p99', colorbar_loc=None)
        # Get the current axis object
        ax = axs[i]
        cbar = plt.colorbar(ax.collections[0], orientation='vertical',shrink=.4,pad=.01)

for j in range(len(genes_of_interest), len(axs)):
    fig.delaxes(axs[j])
plt.ioff()
plt.tight_layout()
plt.savefig('feature_plot_allp99.pdf', dpi=300)
plt.tight_layout()
plt.savefig('feature_plot_allp99.png', dpi=300)
